# %% [markdown]
# ### Циклы

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 28

# %%
# Out:
# 120

# %%
# Out:
# 47163321.0
# 0

# %%
# Out:
# 883

# %% [markdown]
# ### Выполнить перевод из 10ной СИ в 4ную

# %%
# Out:
# 1323

# %% [markdown]
# ### Выполнить перевод из 37ной СИ в 10ную

# %%
# Out:
# 313873
