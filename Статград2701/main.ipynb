# %% [markdown]
# ![image.png](attachment:dec13eab-f2b0-4d90-a253-041ddf42ef3d.png)

# %%
from itertools import*
def f(z,x,w,y):
    return ((not(w)) or ((z<=x)<=y))
for a1,a2,a3,a4,a5,a6,a7 in product([0,1], repeat = 7):
    table = [(a1,0,a2,a3),(0,1,a4,0),(a5,a6,a7,1)]
    if len(table) == len(set(table)):
        for p in permutations('zxwy'):
            if [f(**dict(zip(p,row))) for row in table] == [0,0,0]:
                print(*p)
# Out:
# y x w z

# %% [markdown]
# ![image.png](attachment:68f73d15-1b7c-4e19-9762-313798af226d.png)

# %%
def f(x):
    c=''
    while x!=0:
        c=c+str(x%3)
        x=x//3
    return c[::-1]
for n in range(3,1000):
    b=f(n)
    if n%3==0:
        b=b+b[-2:]
    else:
        z=f(sum(map(int,b))*3)
        b=b+str(z)
    if int(b,3)>600 and int(b,3)<900:
        print(int(b,3))
#810
# Out:
# 606
# 636
# 690
# 720
# 792
# 846
# 876
# 627
# 648
# 678
# 708
# 729
# 744
# 759
# 789
# 810
# 840
# 870
# 891

# %% [markdown]
# ![image.png](attachment:2a2490e3-9634-476f-a5db-17d780abdd40.png)

# %%
import math
# print(math.ceil(math.log2(1568)))
print((11*1195*1024*367)/17094834/60)
#4
# Out:
# 4.816266091459755

# %% [markdown]
# ![image.png](attachment:485d61b7-b5dc-4114-be0e-bf8fc5672753.png)

# %%
from itertools import*
k=0
for x in product(sorted('ОДСАЦЛФЩ'),repeat=4):
    a=''.join(x)
    k+=1
    if k%2!=0 and a[0]!='А' and a[3]!='А' and a.count('Л')>=3:
        print(k)
#659
# Out:
# 659
# 1043
# 1107
# 1155
# 1163
# 1171
# 1173
# 1175
# 1179
# 1187
# 1195
# 1203
# 1211
# 1235
# 1299
# 1363
# 1427
# 1491
# 1683
# 2195
# 2707
# 3219
# 3731

# %% [markdown]
# ![image.png](attachment:3caa2b56-5225-4f6b-907e-d246877daaa0.png)

# %%
f=open('9.txt').readlines()
for i in range(len(f)-1, -1, -1):
    a=[int(x) for x in f[i].split()]
    b=[x for x in a if a.count(x)==1]
    c=[x for x in a if a.count(x)>1]
    b1=[x for x in a if a.count(x)==3]
    b2=[x for x in a if a.count(x)==2]
    # 1 1 2 2 3 3 4
    if len(set(b1))==1 and len(set(b2))==1 and len(set(b))==2 and sum(b)<=min(c):
        print(abs(min(c)))
        break

#448
# Out:
# 448

# %% [markdown]
# ![image.png](attachment:9c1dfdb7-27da-49c0-a32e-d5ff95142405.png)

# %%
from math import *
print(ceil(log2(14170+10+26)))
print(16*1024*1024/156314)
print(108*8/14)
#62
# Out:
# 14
# 107.33021994191179
# 61.714285714285715

# %% [markdown]
# ![image.png](attachment:71fc6e4e-c2c8-4b16-9562-8c4d44bc188f.png)

# %%
a=sorted('1234567890qwertyuiopasdfghjklzxcvbnm')[:21]
for x in a:
    z=int('2331768' + x + '3',21)+int('2496' + x + '2',21)+int('8' + x +'223',21)
    if z%20==0:
        print(z//20)
        break
# Out:
# 4066120204

# %% [markdown]
# ![image.png](attachment:dfebe6f1-bfd1-47c8-a280-34d5f1b7b5b5.png)

# %%
for a in range(1,1000):
    f=0
    for x in range(1,100000):
        for y in range(1,500):
            z=(y<a) and (x<a) or (89241<5*y+x)
# y = 1
# x = 89236

# x = 1
# y = 18000
            
# 89241 >= 5y+x
# A>x
# A>y
# min(A) - ?
            
# 89237
# Out:
#   Cell In[31], line 4
#     for y in range(1,500):
#                           ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# ![image.png](attachment:8e372b1d-0c22-42b0-bd0f-db3666a957ef.png)

# %%
f={}
g={}
for n in range(384242+100, 0, -1):
    if n>=384242:
        g[n]=n/4+18
    if n<384242:
        g[n]=12+g[n+41]
for n in range(13, 1000):
    if n>=20:
        f[n]=f[n-4]+4620
    if n<20:
        f[n]=8*(g[n-12]-21)
print(f[913])
print(384242/41)
#2703082
# Out:
# 2703082.0
# 9371.756097560976

# %% [markdown]
# ![image.png](attachment:49d9247a-0eca-473f-80a2-ac2eddef25f6.png)

# %%
res=[]
a=[int(x) for x in open('17.txt')]
mx=max([x for x in a if abs(x)%100==70])
for i in range(len(a)-2):
    # Когда у нас от 3 и более чисел задействуется, то проще обозначить их переменными:
    # c1,c2,c3 = a[i:i+3]
    if a[i]>0 and a[i+1]>0 and a[i+2]>0 and (a[i]+a[i+1]+a[i+2])<=mx: #Не больше - это <=
        res.append(a[i]+a[i+1]+a[i+2])
print(len(res),max(res))
# Out:
# 152 93769

# %% [markdown]
# ![image.png](attachment:d0bb3e68-4963-4511-a4e4-8317bb8ef79c.png)

# %%
def f(s,e):
    if s>e or s==17 or s==28:
        return 0
    if s==e:
        return 1
    # Тут повезло, но всегда нужно смотреть, что главнее. 
    # Всё, что содержит return 0 ставить выше return 1 в данном задании
    # if s==17:
    #     return 0
    # if s==28:
    #     return 0
    return f(s+2,e)+f(s+3,e)+f(s*2,e)
print(f(8,14)*f(14,18)*f(18,48))
# Out:
# 2244

# %% [markdown]
# ![image.png](attachment:ab8cb0d1-ecae-480b-ac83-eb91a6a615e7.png)

# %%
f=open('24.txt').readline()[::-1]
c=0
mn=10000
for el in f:
    c+=1
    if el in 'AEIOUY':
        k=0
        c=1
    if el=='T':
        k+=1
        if k==63:
            mn=min(c,mn)
print(mn)
# Out:
# 112

# %%
def f(s,m):
    if s<=1207:
        return m%2==0
    if m==0:
        return 0
    h=[f(s-3,m-1),f(s-5,m-1),f(s//4,m-1)]
    return any(h) if m%2!=0 else all(h)
print('19: ', min([s for s in range(1208,10000) if not f(s,1) and f(s,2)]))
print('20: ', [s for s in range(1208,5000) if not f(s,1) and f(s,3)][:2])
print('21: ', min([s for s in range(1208,5000) if not f(s,2) and f(s,4)]))
# Out:
# 19:  4832
# 20:  [4835, 4836]
# 21:  4840

# %% [markdown]
# ![image.png](attachment:d1f04848-cf59-4c03-a2b1-beaff1384bc2.png)

# %%
def f(x):
    res=[]
    for n in range(1,int(x**0.5)+1):
        if x%n==0:
            res.append(x//n)
            res.append(n)
    return set(res)

k=0
for n in range(1_000_000_000-1,100_000_000,-1):
    b=f(n)
    # len(b)+t=n
    if (n-len(b))%23==0:
        k+=1
        print(n)
        if k==5:
            break
# Out:
# 999999961
# 999999789
# 999999740
# 999999731
# 999999690
