# %% [markdown]
# ![image.png](attachment:b029f01a-9705-4a42-b93d-e0e6836a0c10.png)

# %% [markdown]
# ![image.png](attachment:96593eb0-b133-45b9-9481-0187df018eb8.png)

# %% [markdown]
# ![image.png](attachment:3242eb0e-af57-450f-adf3-056c5f76a397.png)

# %% [markdown]
# ![image.png](attachment:769c5a37-3e40-43ac-81b2-1fdea28bcce8.png)
